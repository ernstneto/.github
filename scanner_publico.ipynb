# %% [markdown]
# <a href="https://colab.research.google.com/github/ernstneto/.github/blob/main/scanner_publico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🛡️ Scanner de SSL Pinning (TCC Defense in Depth)
# @markdown Digite a URL que deseja testar e clique no botão de "Play" à esquerda.

# %%
url_alvo = "github.com" # @param {type:"string"}
pin_esperado = "" # @param {type:"string"}

# %%
import ssl
import socket
import hashlib
import sys

# %%
def tester_site(hosname, pin=None):
    print(f"🔄 Conectando em {hostname} para auditoria...")
    try:
        with socket.create_connection((hostname, 443), timeout=5):
            with context.wrap_socket(sock, server_hostname=hostname) as ssock:
                cert_bin = ssock.getpeercert(binary_form=True)
                sha256_hash = hashlib.sha256(cert_bin).hexdigest()

                print(f"✅ Certificado Recebido com Sucesso!")
                print(f"🔒 Fingerprint (SHA-256): {sha256_hash}")

                if pin:
                    if pin == sha256_hash:
                        print("\n🎉 SUCESSO: O Pinning bateu! Conexão Segura.")
                    else:
                        print("\n🚨 ALERTA: O Pinning FALHOU!")
                        print(f"Esperado: {pin}")
                        print(f"Recebido: {sha256_hash}")
                else:
                    print("\nℹ️ Modo Scanner: Apenas exibindo o hash (sem validação de PIN).")
    except Exception as e:
        print(f"❌ Erro ao conectar: {e}")

host_limpo = url_alvo.replace("https://", "").replace("http://", "").split("/")[0]
testar_site(host_limpo, pin_esperado if pin_esperado else None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2988416045.py in <cell line: 0>()
#      22         print(f"❌ Erro ao conectar: {e}")
#      23
# ---> 24 host_limpo = url_alvo.replace("https://", "").replace("http://", "").split("/")[0]
#      25 testar_site(host_limpo, pin_esperado if pin_esperado else None)
#
# NameError: name 'url_alvo' is not defined
